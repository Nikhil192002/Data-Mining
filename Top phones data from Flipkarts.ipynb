# %%
import requests
from bs4 import BeautifulSoup
import pa

# %%
#we have extracted all the links
#now we we get data of first page
Product_Name=[]
Price=[]
Description=[]
Reviews=[]
for i in range(2,5):
    url="https://www.flipkart.com/search?q=mobile+under+50000&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page="+str(i)
    r=requests.get(url)
    soup=BeautifulSoup(r.text,"lxml")
#np=soup.find("a",class_="_1LKTO3").get("href")
#cnp="https://www.flipkart.com"+np
#print(cnp)
#go to div tag of phone name and copy class

    box =soup.find("div",class_="_1YokD2 _3Mn1Gg")#full page data
    names=box.find_all("div",class_="_4rR01T")#names data
    for i in names:
        name =i.text
        Product_Name.append(name)
    print(len(Product_Name))
    prices=box.find_all("div",class_="_30jeq3 _1_WHN1")
    for i in prices:
        name =i.text
        Price.append(name)
    print(len(Price))
    description=box.find_all("ul",class_="_1xgFaf")# description=box.find_all("span",class_="_1xgFaf")
    for i in description:
        name =i.text
        Description.append(name)
    print(len(Description))
    reviews=box.find_all("div",class_="_3LWZlK")
    for i in reviews:
        name =i.text
        Reviews.append(name)
    print(len(Reviews))
# Out:
# 24
# 24
# 24
# 24
# 48
# 48
# 48
# 48
# 72
# 72
# 72
# 72

# %%
#full page data
#soup=soup.find_all("div",class_="_36fx1h _6t1WkM _3HqJxg")

# %%
df=pd.DataFrame({"product name":Product_Name,"prices":Price,"Description":Description,"Reviews":Reviews})

# %%
df
# Out:
#                                          product name   prices  \
# 0                   Mi 10T Pro (Cosmic Black, 128 GB)  ₹47,999
# 1        Tecno Phantom X2 Pro (Stardust Grey, 256 GB)  ₹41,499
# 2                 APPLE iPhone 6 Plus (Silver, 64 GB)  ₹48,999
# 3   Tecno Phantom X2 Pro Retractable 50MP Portrait...  ₹41,499
# 4         OPPO Reno7 Pro 5G (Startrails Blue, 256 GB)  ₹47,990
# ..                                                ...      ...
# 67               Honor 90 5G (Diamond Silver, 256 GB)  ₹29,990
# 68                          vivo V29 5G (Red, 256 GB)  ₹36,999
# 69                         vivo V29 5G (Blue, 256 GB)  ₹36,999
# 70              Nothing Phone (2) (Dark Grey, 128 GB)  ₹39,999
# 71           OnePlus Nord 3 5G (Tempest Gray, 256 GB)  ₹35,938
#
#                                           Description Reviews
# 0   8 GB RAM | 128 GB ROM16.94 cm (6.67 inch) Full...     4.2
# 1   12 GB RAM | 256 GB ROM17.27 cm (6.8 inch) Full...       4
# 2   64 GB ROM13.97 cm (5.5 inch) Retina HD Display...     4.5
# 3   12 GB RAM | 256 GB ROM17.27 cm (6.8 inch) Full...     4.2
# 4   12 GB RAM | 256 GB ROM | Expandable Upto 7 GB1...     4.3
# ..                                                ...     ...
# 67  8 GB RAM | 256 GB ROM17.02 cm (6.7 inch) Displ...     4.2
# 68  12 GB RAM | 256 GB ROM17.22 cm (6.78 inch) Ful...     4.4
# 69  12 GB RAM | 256 GB ROM17.22 cm (6.78 inch) Ful...     4.4
# 70  8 GB RAM | 128 GB ROM17.02 cm (6.7 inch) Full ...     4.4
# 71  16 GB RAM | 256 GB ROM17.12 cm (6.74 inch) Dis...     4.4
#
# [72 rows x 4 columns]

# %%
df.to_csv("C:/Users/DELL/Downloads/Flipkart_mobile_under50000.csv")
